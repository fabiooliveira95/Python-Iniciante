# %% [markdown]
# questao 1 qual tema voce ira tratat? justifique
# *loja online (e-commerce): vensdas de prudutos fisicos ou digitais*
#
#
# questao 2 pretende vender ou oferecer algo? justifique
# *sim eletronicos*
#
# questao 3 qual imagem para a logo do seu site? encaminhe o print juntamente com as resposta
# (" ![Captura de tela de 2023-09-15 12-11-35.png](data:image/png;base64,...) ")
#
#
# questao 4 quais tecnologia alen do python e do django sao complementares ao seu projeto? justifique
# ("bem e mais recomendadas e ultilizar ou liguagem de programacao para sites HTML OU CSS")
#
#
# questao 5 Descreva e justifique quais requisitos de usabilidades, acessibilidas compatibilidades sao desejaveis em sua aplicacao.justifique
#
# (".navegacao intuitiva: o site deve ser facil de navegar, com menus claros e  organizados de forma logica. os usuarios devem conseguir encontra o que procura rapidamente.
# ".contraste adequado: garanti que haja contraste suficiente entre texto e fundo para facilitar leitura para pessoa com baixa visao.
# .testa em navegadores: verifica a compatibilidades de sites com os principais nevegadores, como chrome, firefox, safari e adge.")
#
# questao 6 como voce organizaria o menu? justifique
# ("o menu prcisa conter as principais secoes do site para que o usuario encontre com facilidades com um clique o que vai exatamente encontrar.")
#
# questao 7 quais sao os recurso do seu projeto que contribuem para um maior valor agregado para o seu cliente? justifique
# (" segurança: ganrantir a segurança dos dados dos clientes e fundamental para construir confiança. isso inclui a protecao contra ameaças ciberneticas e o uso responsavel dos dados do cliente.")
#
# questao 8 qual maior dificuldade voce esta considerando para o densenvolvimento do projeto e como pensa em sulucionar? justifique
# ("uma das maiores dificuldades no desenvolvimento do site e a gestao de projetos ea  cordenaçao entre as diferenças equipes envolvidas, como disignes, desenvolvedores, testadores e gerentes de projeto. muitas vezes, os projetos de desenvolvimento web envolvem prazos apertados, requisitos em constante mudança e a necessidade de garantir a qualidade do produto final.")
#
# questao 9 quais melhorias futuras voce deseja implementar em seu projeto? justifique
# ("garanti que o site seja seguro especialmente se voce coletar informacoes pessoais dos usuarios. isso envolve a instalacoa de certificados SSL e aplicacao de praticas de segurança recomendadas")

# %% [markdown]
# ![Captura de tela de 2023-09-15 13-00-08.png](data:image/png;base64,...)

# %%
# !pip install django

# %%
# !django-admin startproject meuProjeto

# %%
# !ls

# %%
# %cd /content/drive/MyDrive/ColabNotebooks/projetos/djangoproject/helloworld
# Out:
# /content/drive/MyDrive/ColabNotebooks/projetos/djangoproject/helloworld

# %%
from google.colab.output import eval_js
print(eval_js("google.colab.kernel.proxyPort(8080)"))
# Out:
# https://br5x0ce5td8-496ff2e9c6d22116-8080-colab.googleusercontent.com/

# %%
ALLOWED_HOSTS = ['colab.research.google.com']

# %%
# !python manage.py runserver
